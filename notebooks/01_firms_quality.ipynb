# %% [markdown]
# # 01 · FIRMS Data Quality
#
# Schema validation, confidence-level breakdown, and duplicate/near-duplicate detection assessment ahead of preprocessing. See docs/data_sources.md.

# %%
from thermal_intelligence.data.validation import validate_firms_schema

# report = validate_firms_schema(df)
# print(report.is_valid, report.errors)
