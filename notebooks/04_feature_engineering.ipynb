# %% [markdown]
# # 04 · Feature Engineering
#
# Build and sanity-check the full model-ready feature table against config/features/feature_schema.yaml.

# %%
from thermal_intelligence.features.context import assemble_feature_table

# feature_table = assemble_feature_table(df, df["event_id"])
# feature_table.info()
