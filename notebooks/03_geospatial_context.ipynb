# %% [markdown]
# # 03 · Geospatial Context
#
# Join clustered events against OSM land-use/industrial/road layers; inspect distance-to-context distributions across districts.

# %%
from thermal_intelligence.geospatial import distance, osm, spatial_features

# landuse = osm.load_landuse_layer("data/raw/osm/maharashtra_landuse.gpkg")
# centroids = spatial_features.event_centroids(df)
