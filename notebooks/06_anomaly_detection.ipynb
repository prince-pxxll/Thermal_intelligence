# %% [markdown]
# # 06 · Anomaly Detection
#
# Fit the Isolation Forest anomaly detector and inspect flagged events against seasonal/spatial baselines.

# %%
from thermal_intelligence.models.anomaly import fit_anomaly_detector, score_anomalies

# model, scaler = fit_anomaly_detector(feature_table)
# scores = score_anomalies(model, scaler, feature_table)
