# %% [markdown]
# # 05 · Baseline Model
#
# Train and inspect the baseline event-type classifier (GradientBoostingClassifier). Compare against a majority-class baseline.

# %%
from thermal_intelligence.models.classification import train

# result = train(labeled_feature_table)
# print(result.test_accuracy)
