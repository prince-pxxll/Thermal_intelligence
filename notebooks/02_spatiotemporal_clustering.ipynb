# %% [markdown]
# # 02 · Spatiotemporal Clustering
#
# Explore ST-DBSCAN parameter choices (spatial_eps_km, temporal_eps_hours, min_samples) and their effect on event cluster counts. See docs/methodology.md section 3 and docs/assumptions.md.

# %%
from thermal_intelligence.geospatial.clustering import st_dbscan, assign_event_ids

# labels = st_dbscan(df, spatial_eps_km=1.0, temporal_eps_hours=48)
# df["event_id"] = assign_event_ids(df.assign(cluster_id=labels))
