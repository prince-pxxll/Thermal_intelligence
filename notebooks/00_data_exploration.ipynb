# %% [markdown]
# # 00 · Data Exploration
#
# Initial look at raw FIRMS detections over Maharashtra: volume, confidence distribution, spatial coverage, and temporal patterns before any cleaning.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from thermal_intelligence.config.settings import get_settings

settings = get_settings()
raw_dir = settings.data_root / "raw" / "firms"
files = sorted(raw_dir.glob("*.csv"))
print(f"Found {len(files)} raw FIRMS file(s)")

# df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
# df.describe(include="all")
