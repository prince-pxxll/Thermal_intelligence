# %% [markdown]
# # 07 · Evaluation
#
# End-to-end evaluation: classification metrics, clustering validity, precision@k for risk-score prioritization, and final risk-score distribution.

# %%
from thermal_intelligence.models.evaluation import (
    classification_metrics, clustering_validity, precision_at_k,
)

# metrics = classification_metrics(y_true, y_pred)
